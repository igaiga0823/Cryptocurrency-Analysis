# %%
import json

with open("data/all_symbol_data.json") as f:
    all_data = json.load(f)

with open("data/all_symbol.json") as f:
    all_symbol_data = json.load(f)

all_symbol_data
# Out:
# ['1000SATSFDUSD',
#  '1000SATSUSDC',
#  '1000SATSUSDT',
#  '1INCHBTC',
#  '1INCHUSDT',
#  '1MBABYDOGEUSDT',
#  'AAVEBTC',
#  'AAVEUSDC',
#  'AAVEUSDT',
#  'ACAUSDT',
#  'ACEUSDT',
#  'ACHUSDT',
#  'ACMUSDT',
#  'ADABTC',
#  'ADAETH',
#  'ADAFDUSD',
#  'ADAUSDC',
#  'ADAUSDT',
#  'ADXUSDT',
#  'AERGOUSDT',
#  'AEURUSDT',
#  'AEVOUSDT',
#  'AGLDBTC',
#  'AGLDUSDT',
#  'AIUSDT',
#  'AKROUSDT',
#  'ALCXUSDT',
#  'ALGOBTC',
#  'ALGOUSDC',
#  'ALGOUSDT',
#  'ALICEUSDT',
#  'ALPACAUSDT',
#  'ALPHABTC',
#  'ALPHAUSDT',
#  'ALPINEUSDT',
#  'ALTFDUSD',
#  'ALTUSDC',
#  'ALTUSDT',
#  'AMBUSDT',
#  'AMPUSDT',
#  'ANKRBTC',
#  'ANKRUSDT',
#  'APEBTC',
#  'APEUSDT',
#  'API3USDT',
#  'APTUSDC',
#  'APTUSDT',
#  'ARBBTC',
#  'ARBFDUSD',
#  'ARBTC',
#  'ARBUSDC',
#  'ARBUSDT',
#  'ARDRUSDT',
#  'ARKMUSDC',
#  'ARKMUSDT',
#  'ARKUSDT',
#  'ARPABTC',
#  'ARPAUSDT',
#  'ARUSDC',
#  'ARUSDT',
#  'ASRUSDT',
#  'ASTRUSDT',
#  'ASTUSDT',
#  'ATABTC',
#  'ATAUSDT',
#  'ATMUSDT',
#  'ATOMBTC',
#  'ATOMETH',
# ...

# %% [markdown]
# ## 価値のない銘柄の基準を満たしている銘柄の分析
#
# 1.	価格の急激な下落: 過去の最高値から90％以上の減少。
# 2.	低取引量: 一定の取引量を下回っているもの

# %%
-0.013
-0.4856
-0.4434
-0.2967
-0.2551
-0.2609
-0.2054
